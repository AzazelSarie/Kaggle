# %% [markdown]
# <a href="https://colab.research.google.com/github/AzazelSarie/Kaggle/blob/main/CNN_V1_TPU_Petals_to_the_Metal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow
# !pip install tensorflow-addons
# !pip install tensorflow-io
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.66.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.10/dist-packages (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (24.1)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (2.13.3)
# Collecting tensorflow-io
#   Downloading tensorflow_io-0.37.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.37.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-io) (0.37.1)
# Downloading tensorflow_io-0.37.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 MB 25.5 MB/s eta 0:00:00
# Installing collected packages: tensorflow-io
# Successfully installed tensorflow-io-0.37.1

# %%
import tensorflow as tf
import os
import tensorflow_addons as tfa
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
import numpy as np
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras import regularizers

# %%
# Define constants
IMG_SIZE = 64
BATCH_SIZE = 32
AUTOTUNE = tf.data.experimental.AUTOTUNE

# Define the feature description based on your TFRecord structure
def _parse_image_function(example_proto):
    feature_description = {
        'image': tf.io.FixedLenFeature([], tf.string),  # Image bytes
        'class': tf.io.FixedLenFeature([], tf.int64),   # Image label (int)
        'id': tf.io.FixedLenFeature([], tf.string),     # Unique ID (optional)
    }
    return tf.io.parse_single_example(example_proto, feature_description)

# Function to decode the image bytes and resize
def decode_image(image):
    image = tf.io.decode_jpeg(image, channels=3)  # Decode JPEG image to 3 channels (RGB)
    image = tf.image.resize(image, [IMG_SIZE, IMG_SIZE])  # Resize the image
    image = image / 255.0  # Normalize pixel values to [0, 1]
    return image

# Combine parsing and decoding to return both image and label
def load_and_process_image(example_proto):
    # Parse the example proto
    parsed_record = _parse_image_function(example_proto)
    image = decode_image(parsed_record['image'])  # Decode image
    label = parsed_record['class']  # Get the class label
    return image, label  # Return both the image and label

# Define the data augmentation function
def augment_image(image, label):
    # Apply data augmentation to the image
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    image = tf.image.random_brightness(image, max_delta=0.2)  # Adjust brightness
    image = tf.image.random_contrast(image, lower=0.8, upper=1.2)  # Adjust contrast
    image = tf.image.random_saturation(image, lower=0.8, upper=1.2)  # Adjust saturation
    image = tf.image.random_hue(image, max_delta=0.2)  # Adjust hue
    image = tf.image.rot90(image, k=tf.random.uniform(shape=[], minval=0, maxval=4, dtype=tf.int32))  # Rotate

    return image, label

# List all TFRecord files
folder_path = "/content/Flower_NN/Train"  # Update this path to your folder
file_pattern = os.path.join(folder_path, "*.tfrec")

# Load the list of files using TensorFlow's Dataset API
file_paths = tf.data.Dataset.list_files(file_pattern)

def load_dataset_with_errors_ignored(file_paths):
    dataset = tf.data.TFRecordDataset(file_paths)
    dataset = dataset.map(load_and_process_image, num_parallel_calls=AUTOTUNE)
    # Use the experimental function to ignore corrupted records
    dataset = dataset.apply(tf.data.experimental.ignore_errors())
    return dataset

# Load the dataset
train_dataset = load_dataset_with_errors_ignored(file_paths)
train_dataset = train_dataset.map(augment_image, num_parallel_calls=AUTOTUNE)

# Batch, shuffle, and prefetch the dataset for efficient loading
train_dataset = train_dataset.shuffle(buffer_size=1000).batch(BATCH_SIZE).prefetch(AUTOTUNE)

# %%
# Function to extract the class (label) from the parsed dataset
def extract_label(example_proto):
    # Parse the example proto (adjust this according to your TFRecord structure)
    feature_description = {
        'image': tf.io.FixedLenFeature([], tf.string),
        'class': tf.io.FixedLenFeature([], tf.int64),
        'id': tf.io.FixedLenFeature([], tf.string),
    }
    parsed_record = tf.io.parse_single_example(example_proto, feature_description)
    return parsed_record['class']  # Return only the class (label)

# Function to load dataset (without batching, to get all labels)
def load_labels(file_paths):
    dataset = tf.data.TFRecordDataset(file_paths)
    dataset = dataset.map(extract_label)  # Only extract the labels
    return dataset

# Load dataset function with ignore_errors
def load_dataset_with_errors_ignored(file_paths):
    dataset = tf.data.TFRecordDataset(file_paths)
    dataset = dataset.map(extract_label, num_parallel_calls=AUTOTUNE)
    dataset = dataset.apply(tf.data.experimental.ignore_errors())  # Ignore corrupted records
    return dataset

# Get the dataset of labels with error handling
label_dataset = load_dataset_with_errors_ignored(file_paths)

# Collect unique labels
unique_labels = set()
for label in label_dataset:
    unique_labels.add(label.numpy())  # Convert Tensor to numpy and add to the set

# Calculate the number of unique classes
num_classes = len(unique_labels)
print(f"Number of unique classes in the dataset: {num_classes}")
# Out:
# Number of unique classes in the dataset: 104

# %%
for image_batch, label_batch in train_dataset.take(1):
    print("Image batch shape:", image_batch.shape)
    print("Label batch shape:", label_batch.shape)
    print("First image in batch:", image_batch[0])
    print("First label in batch:", label_batch[0])
# Out:
# Image batch shape: (32, 64, 64, 3)
# Label batch shape: (32,)
# First image in batch: tf.Tensor(
# [[[0.3636907  0.15994547 0.29591978]
#   [0.3678013  0.18464172 0.3032109 ]
#   [0.3760225  0.19698004 0.29971683]
#   ...
#   [0.3636907  0.07760292 0.28319782]
#   [0.3636907  0.09407142 0.30221078]
#   [0.35135892 0.10644241 0.29781264]]
#
#  [[0.3760225  0.15580875 0.31394142]
#   [0.3636907  0.176414   0.3025813 ]
#   [0.3678013  0.192876   0.28801462]
#   ...
#   [0.3678013  0.08994779 0.2968148 ]
#   [0.3636907  0.08583716 0.2927042 ]
#   [0.35135892 0.0899739  0.27468258]]
#
#  [[0.3636907  0.15582836 0.29528368]
#   [0.3678013  0.18052459 0.30669188]
#   [0.3760225  0.19698004 0.29971683]
#   ...
#   [0.3678013  0.08171353 0.28730842]
#   [0.37191188 0.1022926  0.31043184]
#   [0.35135892 0.09820813 0.28418913]]
#
#  ...
#
#  [[0.34037408 0.10199614 0.        ]
#   [0.35270587 0.08882963 0.        ]
#   [0.36503765 0.10336486 0.        ]
#   ...
#   [0.2938106  0.11888525 0.251078  ]
#   [0.26914704 0.09833881 0.22293344]
#   [0.2732576  0.10656653 0.22356303]]
#
#  [[0.33626348 0.10985953 0.        ]
#   [0.3321529  0.09751982 0.        ]
#   [0.35270587 0.09987301 0.        ]
#   ...
#   [0.2938106  0.12300238 0.24759701]
#   [0.26914704 0.10245593 0.21945244]
#   [0.25681525 0.10247552 0.20491186]]
#
#  [[0.33626348 0.11473027 0.        ]
#   [0.3280423  0.10544655 0.        ]
#   [0.33626348 0.08313149 0.        ]
#   ...
#   [0.2855894  0.11066407 0.24285683]
#   [0.26092583 0.09423475 0.21123125]
#   [0.25270465 0.09836495 0.20080125]]], shape=(64, 64, 3), dtype=float32)
# First label in batch: tf.Tensor(73, shape=(), dtype=int64)

# %%
# Function to build a CNN model
def build_model(num_classes):
    model = models.Sequential()

    # 1st Convolutional Block
    model.add(layers.Conv2D(64, (3, 3), activation = 'relu', input_shape=(IMG_SIZE, IMG_SIZE, 3), padding='same', kernel_initializer = 'he_uniform'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    # 2nd Convolutional Block
    model.add(layers.Conv2D(128, (3, 3), activation = 'relu', padding='same', kernel_initializer = 'he_uniform'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    # 3rd Convolutional Block
    model.add(layers.Conv2D(256, (3, 3), activation = 'relu', padding='same', kernel_initializer = 'he_uniform'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    # 4th Convolutional Block
    model.add(layers.Conv2D(512, (3, 3), activation = 'relu', padding='same', kernel_initializer = 'he_uniform'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    # Flatten the output for Dense layers
    model.add(layers.Flatten())

    # Fully connected layer
    model.add(layers.Dense(1024, activation='relu', kernel_regularizer=regularizers.l2(0.0001), kernel_initializer = 'he_uniform'))
    model.add(layers.Dropout(0.2))
    model.add(layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.0001), kernel_initializer = 'he_uniform'))
    model.add(layers.Dropout(0.2))
    model.add(layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.0001), kernel_initializer = 'he_uniform'))
    model.add(layers.Dropout(0.2))
    model.add(layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.0001), kernel_initializer = 'he_uniform'))
    model.add(layers.Dropout(0.2))
    model.add(layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.0001), kernel_initializer = 'he_uniform'))
    model.add(layers.Dropout(0.2))
    model.add(layers.Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.0001), kernel_initializer = 'he_uniform'))
    model.add(layers.Dropout(0.2))

    # Output layer
    model.add(layers.Dense(num_classes, activation='softmax'))  # For multi-class classification

    # Compile the model
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['sparse_categorical_accuracy'])

    return model

# %%
VALID_IMG_SIZE = 64
VALID_BATCH_SIZE = 32

# Define the same image parsing and decoding function
def load_and_process_validation_image(example_proto):
    parsed_record = _parse_image_function(example_proto)  # Reuse your _parse_image_function
    image = decode_image(parsed_record['image'])  # Reuse your decode_image function
    label = parsed_record['class']
    return image, label

# Load the TFRecord files for the validation dataset
valid_file_pattern = "/content/Flower_NN/Val"  # Update this with your validation TFRecord path
valid_file_pattern = os.path.join(folder_path, "*.tfrec")

# Load the list of files using TensorFlow's Dataset API
valid_file_paths = tf.data.Dataset.list_files(valid_file_pattern)

def load_validation_dataset(valid_file_paths):
    dataset = tf.data.TFRecordDataset(file_paths)
    dataset = dataset.map(load_and_process_image, num_parallel_calls=AUTOTUNE)
    dataset = dataset.apply(tf.data.experimental.ignore_errors())  # Skip corrupted records
    return dataset

# Load, batch, and prefetch the validation dataset (no shuffling needed for validation)
valid_dataset = load_validation_dataset(valid_file_paths)
valid_dataset = valid_dataset.batch(VALID_BATCH_SIZE).prefetch(AUTOTUNE)

# %%
# Example: Assume you have 5 different classes in your dataset
num_classes = 104  # Replace this with the actual number of classes in your dataset
model = build_model(num_classes)

# Training the model
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=0.0001)
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
history = model.fit(train_dataset, epochs=100, batch_size=32, validation_data=valid_dataset, callbacks=[reduce_lr,early_stop])
# Out:
# Epoch 1/100
# 1204/1204 [==============================] - 209s 171ms/step - loss: 4.6332 - sparse_categorical_accuracy: 0.0603 - val_loss: 4.1562 - val_sparse_categorical_accuracy: 0.0963 - lr: 0.0010
# Epoch 2/100
# 1204/1204 [==============================] - 204s 169ms/step - loss: 4.1134 - sparse_categorical_accuracy: 0.0897 - val_loss: 3.8981 - val_sparse_categorical_accuracy: 0.1082 - lr: 0.0010
# Epoch 3/100
# 1204/1204 [==============================] - 204s 170ms/step - loss: 3.9346 - sparse_categorical_accuracy: 0.1093 - val_loss: 3.7404 - val_sparse_categorical_accuracy: 0.1419 - lr: 0.0010
# Epoch 4/100
# 1204/1204 [==============================] - 200s 166ms/step - loss: 3.8382 - sparse_categorical_accuracy: 0.1255 - val_loss: 3.7001 - val_sparse_categorical_accuracy: 0.1678 - lr: 0.0010
# Epoch 5/100
# 1204/1204 [==============================] - 203s 169ms/step - loss: 3.7537 - sparse_categorical_accuracy: 0.1495 - val_loss: 3.5139 - val_sparse_categorical_accuracy: 0.1804 - lr: 0.0010
# Epoch 6/100
# 1204/1204 [==============================] - 204s 170ms/step - loss: 3.6680 - sparse_categorical_accuracy: 0.1690 - val_loss: 3.5639 - val_sparse_categorical_accuracy: 0.1901 - lr: 0.0010
# Epoch 7/100
# 1204/1204 [==============================] - 201s 167ms/step - loss: 3.5698 - sparse_categorical_accuracy: 0.1848 - val_loss: 3.3449 - val_sparse_categorical_accuracy: 0.2225 - lr: 0.0010
# Epoch 8/100
# 1204/1204 [==============================] - 203s 168ms/step - loss: 3.4900 - sparse_categorical_accuracy: 0.2018 - val_loss: 3.3253 - val_sparse_categorical_accuracy: 0.2233 - lr: 0.0010
# Epoch 9/100
# 1204/1204 [==============================] - 203s 168ms/step - loss: 3.4215 - sparse_categorical_accuracy: 0.2119 - val_loss: 3.1609 - val_sparse_categorical_accuracy: 0.2558 - lr: 0.0010
# Epoch 10/100
# 1204/1204 [==============================] - 203s 169ms/step - loss: 3.3487 - sparse_categorical_accuracy: 0.2283 - val_loss: 3.0567 - val_sparse_categorical_accuracy: 0.2804 - lr: 0.0010
# Epoch 11/100
# 1204/1204 [==============================] - 203s 168ms/step - loss: 3.2800 - sparse_categorical_accuracy: 0.2464 - val_loss: 3.0288 - val_sparse_categorical_accuracy: 0.2915 - lr: 0.0010
# Epoch 12/100
# 1204/1204 [==============================] - 204s 169ms/step - loss: 3.2247 - sparse_categorical_accuracy: 0.2641 - val_loss: 2.8948 - val_sparse_categorical_accuracy: 0.3193 - lr: 0.0010
# Epoch 13/100
# 1204/1204 [==============================] - 203s 168ms/step - loss: 3.1697 - sparse_categorical_accuracy: 0.2792 - val_loss: 2.8155 - val_sparse_categorical_accuracy: 0.3357 - lr: 0.0010
# Epoch 14/100
# 1204/1204 [==============================] - 204s 169ms/step - loss: 3.1185 - sparse_categorical_accuracy: 0.2925 - val_loss: 2.7869 - val_sparse_categorical_accuracy: 0.3520 - lr: 0.0010
# Epoch 15/100
# 1204/1204 [==============================] - 203s 169ms/step - loss: 3.0653 - sparse_categorical_accuracy: 0.3094 - val_loss: 2.7008 - val_sparse_categorical_accuracy: 0.3744 - lr: 0.0010
# Epoch 16/100
# 1204/1204 [==============================] - 202s 168ms/step - loss: 3.0324 - sparse_categorical_accuracy: 0.3241 - val_loss: 2.7294 - val_sparse_categorical_accuracy: 0.3710 - lr: 0.0010
# Epoch 17/100
# 1204/1204 [==============================] - 205s 170ms/step - loss: 2.9903 - sparse_categorical_accuracy: 0.3390 - val_loss: 2.6192 - val_sparse_categorical_accuracy: 0.4084 - lr: 0.0010
# Epoch 18/100
# 1204/1204 [==============================] - 203s 169ms/step - loss: 2.9736 - sparse_categorical_accuracy: 0.3521 - val_loss: 2.6476 - val_sparse_categorical_accuracy: 0.4107 - lr: 0.0010
# Epoch 19/100
# 1204/1204 [==============================] - 203s 168ms/step - loss: 2.9292 - sparse_categorical_accuracy: 0.3627 - val_loss: 2.6165 - val_sparse_categorical_accuracy: 0.4169 - lr: 0.0010
# Epoch 20/100
# 1204/1204 [==============================] - 201s 167ms/step - loss: 2.9010 - sparse_categorical_accuracy: 0.3704 - val_loss: 2.5085 - val_sparse_categorical_accuracy: 0.4431 - lr: 0.0010
# Epoch 21/100
# 1204/1204 [==============================] - 202s 167ms/step - loss: 2.8733 - sparse_categorical_accuracy: 0.3858 - val_loss: 2.5490 - val_sparse_categorical_accuracy: 0.4422 - lr: 0.0010
# Epoch 22/100
# 1204/1204 [==============================] - 198s 164ms/step - loss: 2.8493 - sparse_categorical_accuracy: 0.3930 - val_loss: 2.4466 - val_sparse_categorical_accuracy: 0.4725 - lr: 0.0010
# Epoch 23/100
# 1204/1204 [==============================] - 204s 169ms/step - loss: 2.8209 - sparse_categorical_accuracy: 0.4011 - val_loss: 2.4098 - val_sparse_categorical_accuracy: 0.4714 - lr: 0.0010
# Epoch 24/100
# 1204/1204 [==============================] - 200s 166ms/step - loss: 2.8021 - sparse_categorical_accuracy: 0.4097 - val_loss: 2.4338 - val_sparse_categorical_accuracy: 0.4814 - lr: 0.0010
# Epoch 25/100
# 1204/1204 [==============================] - 199s 165ms/step - loss: 2.7677 - sparse_categorical_accuracy: 0.4228 - val_loss: 2.3769 - val_sparse_categorical_accuracy: 0.4942 - lr: 0.0010
# Epoch 26/100
# 1204/1204 [==============================] - 199s 165ms/step - loss: 2.7620 - sparse_categorical_accuracy: 0.4242 - val_loss: 2.3866 - val_sparse_categorical_accuracy: 0.5015 - lr: 0.0010
# Epoch 27/100
# 1204/1204 [==============================] - 199s 165ms/step - loss: 2.7427 - sparse_categorical_accuracy: 0.4347 - val_loss: 2.3681 - val_sparse_categorical_accuracy: 0.5044 - lr: 0.0010
# Epoch 28/100
# 1204/1204 [==============================] - 201s 167ms/step - loss: 2.7190 - sparse_categorical_accuracy: 0.4459 - val_loss: 2.4404 - val_sparse_categorical_accuracy: 0.5021 - lr: 0.0010
# Epoch 29/100
# 1204/1204 [==============================] - 199s 165ms/step - loss: 2.6873 - sparse_categorical_accuracy: 0.4534 - val_loss: 2.2589 - val_sparse_categorical_accuracy: 0.5344 - lr: 0.0010
# Epoch 30/100
# 1204/1204 [==============================] - 201s 167ms/step - loss: 2.6705 - sparse_categorical_accuracy: 0.4596 - val_loss: 2.2968 - val_sparse_categorical_accuracy: 0.5360 - lr: 0.0010
# Epoch 31/100
# 1204/1204 [==============================] - 202s 167ms/step - loss: 2.6604 - sparse_categorical_accuracy: 0.4642 - val_loss: 2.5610 - val_sparse_categorical_accuracy: 0.4903 - lr: 0.0010
# Epoch 32/100
# 1204/1204 [==============================] - 201s 167ms/step - loss: 2.6497 - sparse_categorical_accuracy: 0.4702 - val_loss: 2.3087 - val_sparse_categorical_accuracy: 0.5416 - lr: 0.0010
# Epoch 33/100
# 1204/1204 [==============================] - 199s 165ms/step - loss: 2.4506 - sparse_categorical_accuracy: 0.5102 - val_loss: 1.9481 - val_sparse_categorical_accuracy: 0.6037 - lr: 2.0000e-04
# Epoch 34/100
# 1204/1204 [==============================] - 202s 168ms/step - loss: 2.3471 - sparse_categorical_accuracy: 0.5257 - val_loss: 1.9097 - val_sparse_categorical_accuracy: 0.6094 - lr: 2.0000e-04
# Epoch 35/100
# 1204/1204 [==============================] - 200s 166ms/step - loss: 2.2745 - sparse_categorical_accuracy: 0.5351 - val_loss: 1.8039 - val_sparse_categorical_accuracy: 0.6289 - lr: 2.0000e-04
# Epoch 36/100
# 1204/1204 [==============================] - 198s 165ms/step - loss: 2.2030 - sparse_categorical_accuracy: 0.5453 - val_loss: 1.7494 - val_sparse_categorical_accuracy: 0.6407 - lr: 2.0000e-04
# Epoch 37/100
# 1204/1204 [==============================] - 198s 164ms/step - loss: 2.1645 - sparse_categorical_accuracy: 0.5546 - val_loss: 1.7364 - val_sparse_categorical_accuracy: 0.6378 - lr: 2.0000e-04
# Epoch 38/100
# 1204/1204 [==============================] - 198s 165ms/step - loss: 2.1157 - sparse_categorical_accuracy: 0.5622 - val_loss: 1.6556 - val_sparse_categorical_accuracy: 0.6556 - lr: 2.0000e-04
# Epoch 39/100
# 1204/1204 [==============================] - 197s 163ms/step - loss: 2.0795 - sparse_categorical_accuracy: 0.5680 - val_loss: 1.6085 - val_sparse_categorical_accuracy: 0.6647 - lr: 2.0000e-04
# Epoch 40/100
# 1204/1204 [==============================] - 199s 165ms/step - loss: 2.0249 - sparse_categorical_accuracy: 0.5758 - val_loss: 1.5568 - val_sparse_categorical_accuracy: 0.6772 - lr: 2.0000e-04
# Epoch 41/100
# 1204/1204 [==============================] - 202s 168ms/step - loss: 2.0007 - sparse_categorical_accuracy: 0.5799 - val_loss: 1.5668 - val_sparse_categorical_accuracy: 0.6721 - lr: 2.0000e-04
# Epoch 42/100
# 1204/1204 [==============================] - 201s 167ms/step - loss: 1.9692 - sparse_categorical_accuracy: 0.5864 - val_loss: 1.5022 - val_sparse_categorical_accuracy: 0.6851 - lr: 2.0000e-04
# Epoch 43/100
# 1204/1204 [==============================] - 197s 164ms/step - loss: 1.9410 - sparse_categorical_accuracy: 0.5926 - val_loss: 1.4651 - val_sparse_categorical_accuracy: 0.6963 - lr: 2.0000e-04
# Epoch 44/100
# 1204/1204 [==============================] - 198s 164ms/step - loss: 1.9051 - sparse_categorical_accuracy: 0.6017 - val_loss: 1.4251 - val_sparse_categorical_accuracy: 0.7024 - lr: 2.0000e-04
# Epoch 45/100
# 1204/1204 [==============================] - 203s 168ms/step - loss: 1.8852 - sparse_categorical_accuracy: 0.6056 - val_loss: 1.4127 - val_sparse_categorical_accuracy: 0.7054 - lr: 2.0000e-04
# Epoch 46/100
# 1204/1204 [==============================] - 200s 166ms/step - loss: 1.8537 - sparse_categorical_accuracy: 0.6098 - val_loss: 1.3686 - val_sparse_categorical_accuracy: 0.7182 - lr: 2.0000e-04
# Epoch 47/100
# 1204/1204 [==============================] - 198s 165ms/step - loss: 1.8244 - sparse_categorical_accuracy: 0.6141 - val_loss: 1.3580 - val_sparse_categorical_accuracy: 0.7176 - lr: 2.0000e-04
# Epoch 48/100
# 1204/1204 [==============================] - 200s 166ms/step - loss: 1.8033 - sparse_categorical_accuracy: 0.6202 - val_loss: 1.3742 - val_sparse_categorical_accuracy: 0.7168 - lr: 2.0000e-04
# Epoch 49/100
# 1204/1204 [==============================] - 203s 168ms/step - loss: 1.7885 - sparse_categorical_accuracy: 0.6265 - val_loss: 1.2984 - val_sparse_categorical_accuracy: 0.7355 - lr: 2.0000e-04
# Epoch 50/100
# 1204/1204 [==============================] - 200s 166ms/step - loss: 1.7545 - sparse_categorical_accuracy: 0.6316 - val_loss: 1.2665 - val_sparse_categorical_accuracy: 0.7431 - lr: 2.0000e-04
# Epoch 51/100
# 1204/1204 [==============================] - 202s 168ms/step - loss: 1.7349 - sparse_categorical_accuracy: 0.6373 - val_loss: 1.2411 - val_sparse_categorical_accuracy: 0.7498 - lr: 2.0000e-04
# Epoch 52/100
# 1204/1204 [==============================] - 200s 166ms/step - loss: 1.7117 - sparse_categorical_accuracy: 0.6404 - val_loss: 1.2437 - val_sparse_categorical_accuracy: 0.7476 - lr: 2.0000e-04
# Epoch 53/100
# 1204/1204 [==============================] - 201s 167ms/step - loss: 1.6931 - sparse_categorical_accuracy: 0.6472 - val_loss: 1.2123 - val_sparse_categorical_accuracy: 0.7554 - lr: 2.0000e-04
# Epoch 54/100
# 1204/1204 [==============================] - 204s 169ms/step - loss: 1.6770 - sparse_categorical_accuracy: 0.6509 - val_loss: 1.1886 - val_sparse_categorical_accuracy: 0.7611 - lr: 2.0000e-04
# Epoch 55/100
# 1204/1204 [==============================] - 203s 168ms/step - loss: 1.6474 - sparse_categorical_accuracy: 0.6573 - val_loss: 1.1706 - val_sparse_categorical_accuracy: 0.7654 - lr: 2.0000e-04
# Epoch 56/100
# 1204/1204 [==============================] - 202s 168ms/step - loss: 1.6216 - sparse_categorical_accuracy: 0.6623 - val_loss: 1.1542 - val_sparse_categorical_accuracy: 0.7692 - lr: 2.0000e-04
# Epoch 57/100
# 1204/1204 [==============================] - 200s 166ms/step - loss: 1.6142 - sparse_categorical_accuracy: 0.6630 - val_loss: 1.1219 - val_sparse_categorical_accuracy: 0.7802 - lr: 2.0000e-04
# Epoch 58/100
# 1204/1204 [==============================] - 201s 167ms/step - loss: 1.5796 - sparse_categorical_accuracy: 0.6738 - val_loss: 1.1054 - val_sparse_categorical_accuracy: 0.7808 - lr: 2.0000e-04
# Epoch 59/100
# 1204/1204 [==============================] - 201s 167ms/step - loss: 1.5774 - sparse_categorical_accuracy: 0.6722 - val_loss: 1.0780 - val_sparse_categorical_accuracy: 0.7913 - lr: 2.0000e-04
# Epoch 60/100
# 1204/1204 [==============================] - 198s 164ms/step - loss: 1.5587 - sparse_categorical_accuracy: 0.6794 - val_loss: 1.0733 - val_sparse_categorical_accuracy: 0.7907 - lr: 2.0000e-04
# Epoch 61/100
# 1204/1204 [==============================] - 199s 165ms/step - loss: 1.5453 - sparse_categorical_accuracy: 0.6845 - val_loss: 1.0548 - val_sparse_categorical_accuracy: 0.7973 - lr: 2.0000e-04
# Epoch 62/100
# 1204/1204 [==============================] - 203s 168ms/step - loss: 1.5302 - sparse_categorical_accuracy: 0.6853 - val_loss: 1.0466 - val_sparse_categorical_accuracy: 0.8006 - lr: 2.0000e-04
# Epoch 63/100
# 1204/1204 [==============================] - 203s 168ms/step - loss: 1.5154 - sparse_categorical_accuracy: 0.6940 - val_loss: 1.0338 - val_sparse_categorical_accuracy: 0.8017 - lr: 2.0000e-04
# Epoch 64/100
# 1204/1204 [==============================] - 200s 166ms/step - loss: 1.4970 - sparse_categorical_accuracy: 0.6955 - val_loss: 1.0249 - val_sparse_categorical_accuracy: 0.8041 - lr: 2.0000e-04
# Epoch 65/100
# 1204/1204 [==============================] - 204s 169ms/step - loss: 1.4780 - sparse_categorical_accuracy: 0.7002 - val_loss: 1.0042 - val_sparse_categorical_accuracy: 0.8107 - lr: 2.0000e-04
# Epoch 66/100
# 1204/1204 [==============================] - 203s 168ms/step - loss: 1.4642 - sparse_categorical_accuracy: 0.7011 - val_loss: 0.9875 - val_sparse_categorical_accuracy: 0.8160 - lr: 2.0000e-04
# Epoch 67/100
# 1204/1204 [==============================] - 202s 168ms/step - loss: 1.4552 - sparse_categorical_accuracy: 0.7044 - val_loss: 0.9763 - val_sparse_categorical_accuracy: 0.8163 - lr: 2.0000e-04
# Epoch 68/100
# 1204/1204 [==============================] - 201s 167ms/step - loss: 1.4360 - sparse_categorical_accuracy: 0.7099 - val_loss: 0.9559 - val_sparse_categorical_accuracy: 0.8244 - lr: 2.0000e-04
# Epoch 69/100
# 1204/1204 [==============================] - 204s 170ms/step - loss: 1.4360 - sparse_categorical_accuracy: 0.7134 - val_loss: 0.9416 - val_sparse_categorical_accuracy: 0.8305 - lr: 2.0000e-04
# Epoch 70/100
# 1204/1204 [==============================] - 199s 166ms/step - loss: 1.4173 - sparse_categorical_accuracy: 0.7162 - val_loss: 0.9385 - val_sparse_categorical_accuracy: 0.8303 - lr: 2.0000e-04
# Epoch 71/100
# 1204/1204 [==============================] - 203s 169ms/step - loss: 1.4034 - sparse_categorical_accuracy: 0.7206 - val_loss: 0.9238 - val_sparse_categorical_accuracy: 0.8342 - lr: 2.0000e-04
# Epoch 72/100
# 1204/1204 [==============================] - 202s 168ms/step - loss: 1.3991 - sparse_categorical_accuracy: 0.7250 - val_loss: 0.9021 - val_sparse_categorical_accuracy: 0.8398 - lr: 2.0000e-04
# Epoch 73/100
# 1204/1204 [==============================] - 201s 167ms/step - loss: 1.3793 - sparse_categorical_accuracy: 0.7282 - val_loss: 0.8978 - val_sparse_categorical_accuracy: 0.8434 - lr: 2.0000e-04
# Epoch 74/100
# 1204/1204 [==============================] - 201s 167ms/step - loss: 1.3699 - sparse_categorical_accuracy: 0.7308 - val_loss: 0.8770 - val_sparse_categorical_accuracy: 0.8507 - lr: 2.0000e-04
# Epoch 75/100
# 1204/1204 [==============================] - 201s 167ms/step - loss: 1.3697 - sparse_categorical_accuracy: 0.7318 - val_loss: 0.8713 - val_sparse_categorical_accuracy: 0.8496 - lr: 2.0000e-04
# Epoch 76/100
# 1204/1204 [==============================] - 199s 165ms/step - loss: 1.3418 - sparse_categorical_accuracy: 0.7363 - val_loss: 0.8609 - val_sparse_categorical_accuracy: 0.8543 - lr: 2.0000e-04
# Epoch 77/100
# 1204/1204 [==============================] - 205s 170ms/step - loss: 1.3382 - sparse_categorical_accuracy: 0.7402 - val_loss: 0.8416 - val_sparse_categorical_accuracy: 0.8571 - lr: 2.0000e-04
# Epoch 78/100
# 1204/1204 [==============================] - 201s 167ms/step - loss: 1.3265 - sparse_categorical_accuracy: 0.7415 - val_loss: 0.8513 - val_sparse_categorical_accuracy: 0.8580 - lr: 2.0000e-04
# Epoch 79/100
# 1204/1204 [==============================] - 203s 168ms/step - loss: 1.3053 - sparse_categorical_accuracy: 0.7484 - val_loss: 0.8505 - val_sparse_categorical_accuracy: 0.8569 - lr: 2.0000e-04
# Epoch 80/100
# 1204/1204 [==============================] - 203s 168ms/step - loss: 1.3025 - sparse_categorical_accuracy: 0.7514 - val_loss: 0.8083 - val_sparse_categorical_accuracy: 0.8684 - lr: 2.0000e-04
# Epoch 81/100
# 1204/1204 [==============================] - 198s 164ms/step - loss: 1.3001 - sparse_categorical_accuracy: 0.7506 - val_loss: 0.8036 - val_sparse_categorical_accuracy: 0.8745 - lr: 2.0000e-04
# Epoch 82/100
# 1204/1204 [==============================] - 199s 165ms/step - loss: 1.2898 - sparse_categorical_accuracy: 0.7541 - val_loss: 0.8215 - val_sparse_categorical_accuracy: 0.8698 - lr: 2.0000e-04
# Epoch 83/100
# 1204/1204 [==============================] - 200s 166ms/step - loss: 1.2764 - sparse_categorical_accuracy: 0.7558 - val_loss: 0.7860 - val_sparse_categorical_accuracy: 0.8753 - lr: 2.0000e-04
# Epoch 84/100
# 1204/1204 [==============================] - 202s 167ms/step - loss: 1.2599 - sparse_categorical_accuracy: 0.7653 - val_loss: 0.7796 - val_sparse_categorical_accuracy: 0.8796 - lr: 2.0000e-04
# Epoch 85/100
# 1204/1204 [==============================] - 201s 167ms/step - loss: 1.2532 - sparse_categorical_accuracy: 0.7640 - val_loss: 0.7663 - val_sparse_categorical_accuracy: 0.8893 - lr: 2.0000e-04
# Epoch 86/100
# 1204/1204 [==============================] - 206s 171ms/step - loss: 1.2401 - sparse_categorical_accuracy: 0.7692 - val_loss: 0.7780 - val_sparse_categorical_accuracy: 0.8809 - lr: 2.0000e-04
# Epoch 87/100
# 1204/1204 [==============================] - 201s 167ms/step - loss: 1.2311 - sparse_categorical_accuracy: 0.7703 - val_loss: 0.7468 - val_sparse_categorical_accuracy: 0.8943 - lr: 2.0000e-04
# Epoch 88/100
# 1204/1204 [==============================] - 198s 164ms/step - loss: 1.2259 - sparse_categorical_accuracy: 0.7727 - val_loss: 0.7450 - val_sparse_categorical_accuracy: 0.8910 - lr: 2.0000e-04
# Epoch 89/100
# 1204/1204 [==============================] - 202s 168ms/step - loss: 1.2188 - sparse_categorical_accuracy: 0.7775 - val_loss: 0.7434 - val_sparse_categorical_accuracy: 0.8940 - lr: 2.0000e-04
# Epoch 90/100
# 1204/1204 [==============================] - 202s 168ms/step - loss: 1.2093 - sparse_categorical_accuracy: 0.7809 - val_loss: 0.7674 - val_sparse_categorical_accuracy: 0.8899 - lr: 2.0000e-04
# Epoch 91/100
# 1204/1204 [==============================] - 198s 165ms/step - loss: 1.2016 - sparse_categorical_accuracy: 0.7798 - val_loss: 0.7215 - val_sparse_categorical_accuracy: 0.8996 - lr: 2.0000e-04
# Epoch 92/100
# 1204/1204 [==============================] - 204s 170ms/step - loss: 1.2006 - sparse_categorical_accuracy: 0.7823 - val_loss: 0.7153 - val_sparse_categorical_accuracy: 0.8995 - lr: 2.0000e-04
# Epoch 93/100
# 1204/1204 [==============================] - 199s 165ms/step - loss: 1.1807 - sparse_categorical_accuracy: 0.7866 - val_loss: 0.7109 - val_sparse_categorical_accuracy: 0.9037 - lr: 2.0000e-04
# Epoch 94/100
# 1204/1204 [==============================] - 199s 165ms/step - loss: 1.1766 - sparse_categorical_accuracy: 0.7897 - val_loss: 0.7093 - val_sparse_categorical_accuracy: 0.9031 - lr: 2.0000e-04
# Epoch 95/100
# 1204/1204 [==============================] - 199s 165ms/step - loss: 1.1748 - sparse_categorical_accuracy: 0.7902 - val_loss: 0.6944 - val_sparse_categorical_accuracy: 0.9061 - lr: 2.0000e-04
# Epoch 96/100
# 1204/1204 [==============================] - 200s 166ms/step - loss: 1.1566 - sparse_categorical_accuracy: 0.7944 - val_loss: 0.6925 - val_sparse_categorical_accuracy: 0.9112 - lr: 2.0000e-04
# Epoch 97/100
# 1204/1204 [==============================] - 199s 165ms/step - loss: 1.1546 - sparse_categorical_accuracy: 0.7960 - val_loss: 0.6821 - val_sparse_categorical_accuracy: 0.9101 - lr: 2.0000e-04
# Epoch 98/100
# 1204/1204 [==============================] - 201s 167ms/step - loss: 1.1541 - sparse_categorical_accuracy: 0.7964 - val_loss: 0.6692 - val_sparse_categorical_accuracy: 0.9162 - lr: 2.0000e-04
# Epoch 99/100
# 1204/1204 [==============================] - 202s 168ms/step - loss: 1.1363 - sparse_categorical_accuracy: 0.8002 - val_loss: 0.6811 - val_sparse_categorical_accuracy: 0.9121 - lr: 2.0000e-04
# Epoch 100/100
# 1204/1204 [==============================] - 201s 167ms/step - loss: 1.1359 - sparse_categorical_accuracy: 0.8014 - val_loss: 0.6697 - val_sparse_categorical_accuracy: 0.9170 - lr: 2.0000e-04

# %%
def load_and_process_test_image(example_proto):
    # Define the feature description for test data (exclude the 'class' field)
    feature_description = {
        'image': tf.io.FixedLenFeature([], tf.string),  # Only image feature
        'id': tf.io.FixedLenFeature([], tf.string)  # Optional: Keep the ID if needed
    }
    parsed_record = tf.io.parse_single_example(example_proto, feature_description)
    image = tf.io.decode_jpeg(parsed_record['image'], channels=3)
    image = tf.image.resize(image, [IMG_SIZE, IMG_SIZE])  # Resize to same size as training
    image = image / 255.0  # Normalize pixel values to [0, 1]
    return image, parsed_record['id']  # Return image and optional ID

# Update load_test_dataset to use the test image parsing function
def load_test_dataset(file_paths):
    dataset = tf.data.TFRecordDataset(file_paths)
    dataset = dataset.map(load_and_process_test_image, num_parallel_calls=AUTOTUNE)
    return dataset

# Assuming test data is in a TFRecord format, load the test dataset
test_file_pattern = "/content/Flower_NN/Test/*.tfrec"
test_file_paths = tf.data.Dataset.list_files(test_file_pattern)
test_dataset = load_test_dataset(test_file_paths)
test_dataset = test_dataset.batch(BATCH_SIZE).prefetch(AUTOTUNE)

# %%
# Use the trained model to predict classes for the test dataset
predictions = model.predict(test_dataset)

# Convert probabilities to predicted classes (e.g., the index with the highest probability)
predicted_classes = tf.argmax(predictions, axis=1).numpy()  # Convert to numpy array
# Out:
# 923/923 [==============================] - 31s 33ms/step

# %%
import pandas as pd

# Extract IDs from the test dataset
ids = []
for _, id_batch in test_dataset:
    ids.extend(id_batch.numpy())

# Create a DataFrame for submission
submission_df = pd.DataFrame({
    'id': ids,
    'label': predicted_classes  # Use predicted class indices
})

# Save to CSV
submission_df.to_csv('submission.csv', index=False)
